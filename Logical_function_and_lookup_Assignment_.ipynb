# %% [markdown]
# #logical function and lookup

# %% [markdown]
# 1. Write a formula to check if the marks in cell B2 are greater than or equal to 40. If yes, return ,"Pass" otherwise "fail".
# ---> =if(B2>40,"pass","fail")

# %% [markdown]
# 2. company gives a bonus  if sales are above 40,000 and attendance is greater than or equal to 90%. Write a formula to calculate whether the employee will get a bonus or not
# --> =if(and(B11>40000,C11>=90),"Bonus","No Bonus")

# %% [markdown]
# 3. write a nested IF formula:
# If marks in are ≥ 90 → , ≥ 75 → , ≥ 50 → , otherwise . B2 "A" "B" "C" "Fai
# ---> =if(B18>=90,"A",if(B18>=75,"b",if(B18>=50,"c")))

# %% [markdown]
# 4. nd the Department of Employee ID = E103. Also explain which LOOKUP function is used and why?
# ---> =vlookup(E27,$A$26:$C$29,3,false)
# --->I used Vlookup formula beacuse the data is Given in the vertically format

# %% [markdown]
# 5. formula is
# --> =vlookup(D34,A33:B36,2,true)

# %% [markdown]
# 6. Write an IF function to check whether an employee has Exceeded their allowed leave balance.
#
# If Leaves Taken > Allowed Leaves, display "Exceeded".
#
# Otherwise, display "OK".
#
# --->=if(B40>C40,"Exceeded","Ok")

# %% [markdown]
# 7. Question No 7
#
# > =index(B46:B49,Match("E105",A46:A49,0))

# %% [markdown]
# 8. Formual is
# > =Xlookup("E303",A53:A56,B53:B56)
